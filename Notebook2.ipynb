# %% [markdown]
# # **TD Detecting Higgs bosons**

# %% [markdown]
# ## I- Pre-processing

# %% [markdown]
# ### 1- Importing libraries

# %%
import numpy as np
import pandas as pd
import csv
import time
import math
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn import model_selection
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ### 2- Reading CSV files
# Data set available in http://opendata.cern.ch/record/328
#
# **If the dataset is very large, you can select a sub-sample to work with.**.

# %%
dataFilename = 'atlas-higgs.csv'
data = pd.read_csv(dataFilename)
print(data.shape)
print(data.dtypes)
data.head()
# Out:
# (818238, 35)
# EventId                          int64
# DER_mass_MMC                   float64
# DER_mass_transverse_met_lep    float64
# DER_mass_vis                   float64
# DER_pt_h                       float64
# DER_deltaeta_jet_jet           float64
# DER_mass_jet_jet               float64
# DER_prodeta_jet_jet            float64
# DER_deltar_tau_lep             float64
# DER_pt_tot                     float64
# DER_sum_pt                     float64
# DER_pt_ratio_lep_tau           float64
# DER_met_phi_centrality         float64
# DER_lep_eta_centrality         float64
# PRI_tau_pt                     float64
# PRI_tau_eta                    float64
# PRI_tau_phi                    float64
# PRI_lep_pt                     float64
# PRI_lep_eta                    float64
# PRI_lep_phi                    float64
# PRI_met                        float64
# PRI_met_phi                    float64
# PRI_met_sumet                  float64
# PRI_jet_num                      int64
# PRI_jet_leading_pt             float64
# PRI_jet_leading_eta            float64
# PRI_jet_leading_phi            float64
# PRI_jet_subleading_pt          float64
# PRI_jet_subleading_eta         float64
# PRI_jet_subleading_phi         float64
# PRI_jet_all_pt                 float64
# Weight                         float64
# Label                           object
# KaggleSet                       object
# KaggleWeight                   float64
# dtype: object
#    EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0   100000       138.470                       51.655        97.827    27.980
# 1   100001       160.937                       68.768       103.235    48.146
# 2   100002      -999.000                      162.172       125.953    35.635
# 3   100003       143.905                       81.417        80.943     0.414
# 4   100004       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
# 1               -999.00          -999.000             -999.000
# 2               -999.00          -999.000             -999.000
# 3               -999.00          -999.000             -999.000
# 4               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  ...  PRI_jet_leading_eta  \
# 0               3.064      41.928  ...                2.150
# 1               3.473       2.078  ...                0.725
# 2               3.148       9.336  ...                2.053
# 3               3.310       0.414  ...             -999.000
# 4               3.891      16.405  ...             -999.000
#
#    PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# 0                0.444                 46.062                    1.24
# 1                1.158               -999.000                 -999.00
# 2               -2.028               -999.000                 -999.00
# 3             -999.000               -999.000                 -999.00
# 4             -999.000               -999.000                 -999.00
#
#    PRI_jet_subleading_phi  PRI_jet_all_pt    Weight  Label  KaggleSet  \
# 0                  -2.475         113.497  0.000814      s          t
# 1                -999.000          46.226  0.681042      b          t
# 2                -999.000          44.251  0.715742      b          t
# 3                -999.000          -0.000  1.660654      b          t
# 4                -999.000           0.000  1.904263      b          t
#
#    KaggleWeight
# 0      0.002653
# 1      2.233584
# 2      2.347389
# 3      5.446378
# 4      6.245333
#
# [5 rows x 35 columns]

# %% [markdown]
# ### 3- Delete superfluous columns
# Use the `del` function to delete the 'EventId', 'Weight', 'KaggleSet', 'KaggleWeight' columns, then transform the 'label' column into 0/1 binary values.

# %%
del(data['EventId'])
del(data['Weight'])
del(data['KaggleSet'])
del(data['KaggleWeight'])
data['Label'] = data['Label'].map({'s': 1, 'b': 0})
data.head()
# Out:
#    DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0       138.470                       51.655        97.827    27.980
# 1       160.937                       68.768       103.235    48.146
# 2      -999.000                      162.172       125.953    35.635
# 3       143.905                       81.417        80.943     0.414
# 4       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
# 1               -999.00          -999.000             -999.000
# 2               -999.00          -999.000             -999.000
# 3               -999.00          -999.000             -999.000
# 4               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  ...  PRI_met_sumet  \
# 0               3.064      41.928     197.760  ...        258.733
# 1               3.473       2.078     125.157  ...        164.546
# 2               3.148       9.336     197.814  ...        260.414
# 3               3.310       0.414      75.968  ...         86.062
# 4               3.891      16.405      57.983  ...         53.131
#
#    PRI_jet_num  PRI_jet_leading_pt  PRI_jet_leading_eta  PRI_jet_leading_phi  \
# 0            2              67.435                2.150                0.444
# 1            1              46.226                0.725                1.158
# 2            1              44.251                2.053               -2.028
# 3            0            -999.000             -999.000             -999.000
# 4            0            -999.000             -999.000             -999.000
#
#    PRI_jet_subleading_pt  PRI_jet_subleading_eta  PRI_jet_subleading_phi  \
# 0                 46.062                    1.24                  -2.475
# 1               -999.000                 -999.00                -999.000
# 2               -999.000                 -999.00                -999.000
# 3               -999.000                 -999.00                -999.000
# 4               -999.000                 -999.00                -999.000
#
#    PRI_jet_all_pt  Label
# 0         113.497      1
# 1          46.226      0
# 2          44.251      0
# 3          -0.000      0
# 4           0.000      0
#
# [5 rows x 31 columns]

# %% [markdown]
# ### 4- Dealing with missing data
# Missing data in this file are designated -999. To replace them, use the `SimpleImputer` class.

# %%
#TRaitement des données manquantes désignes par -999
# Store column names before imputation
column_names = data.columns

imputer = SimpleImputer(missing_values=-999, strategy='median')
data_imputed = imputer.fit_transform(data)

# Convert back to DataFrame with original column names
data = pd.DataFrame(data_imputed, columns=column_names)

# %% [markdown]
# ### Outliers
# Check the dataset for outliers by displaying the boxplots of all columns.

# %%
#affichage des boxplot des différents attributs

data.boxplot(figsize=(15, 10))
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5-  Data calibration with *MinMaxScaler* from Sci-kit Learn
# Scale all columns with the "MinMaxScaler".

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(data)
data_scaled = pd.DataFrame(data_scaled, columns=data.columns)

# %% [markdown]
# **Crossing certain pairs of columns**

# %%
pairs_selected = [
    ('DER_mass_MMC', 'DER_mass_jet_jet'),
    ('DER_mass_MMC', 'DER_prodeta_jet_jet'),
    ('DER_deltaeta_jet_jet', 'DER_prodeta_jet_jet'),
    ('DER_mass_jet_jet', 'DER_deltar_tau_lep'),
    ('DER_mass_jet_jet', 'PRI_jet_leading_eta'),
    ('DER_prodeta_jet_jet', 'PRI_jet_leading_eta'),
    ('PRI_tau_eta', 'PRI_lep_eta'),
    ('PRI_jet_num', 'PRI_jet_subleading_pt')
]
for z in pairs_selected:
    fig, ax = plt.subplots(1, 2, figsize = (10, 4), sharex = True, sharey = True)
    sns.scatterplot(data = data_scaled, x = z[0], y = z[1], ax = ax[0])
    sns.scatterplot(data = data_scaled, x = z[0], y = z[1], ax = ax[1])
    ax[0].set_title("Background events", fontsize = 14)
    ax[1].set_title("Signal events", fontsize = 14)
    plt.tight_layout()

plt.show()

# %% [markdown]
# ## Unbalance Ratio
# Display the histogram of the target column to check the existence of a disequilibrium between the positive and negative classes.

# %%
plt.hist(data_scaled['Label'])
plt.show()
print(data_scaled['Label'].value_counts())
print(data_scaled.sample)
# Out:
# Label
# 0.0    538678
# 1.0    279560
# Name: count, dtype: int64
# <bound method NDFrame.sample of         DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0           0.066707                     0.053326      0.068128  0.009869
# 1           0.078287                     0.070992      0.072155  0.016983
# 2           0.053322                     0.167417      0.089071  0.012570
# 3           0.069508                     0.084050      0.055557  0.000146
# 4           0.085980                     0.017462      0.095662  0.005787
# ...              ...                          ...           ...       ...
# 818233      0.049801                     0.047945      0.039999  0.055094
# 818234      0.046515                     0.031070      0.041983  0.023231
# 818235      0.051259                     0.010155      0.043797  0.006351
# 818236      0.045184                     0.020653      0.045132  0.010498
# 818237      0.042948                     0.082700      0.053082  0.001405
#
#         DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                   0.104310          0.022395             0.591293
# 1                   0.240830          0.042849             0.511920
# 2                   0.240830          0.042849             0.511920
# 3                   0.240830          0.042849             0.511920
# 4                   0.240830          0.042849             0.511920
# ...                      ...               ...                  ...
# 818233              0.046194          0.006882             0.544106
# 818234              0.379642          0.092256             0.447357
# 818235              0.240830          0.042849             0.511920
# 818236              0.240830          0.042849             0.511920
# 818237              0.240830          0.042849             0.511920
#
#         DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  ...  PRI_met_sumet  \
# 0                 0.515244    0.014789    0.074595  ...       0.112586
# 1                 0.589031    0.000733    0.038884  ...       0.069314
# 2                 0.530399    0.003293    0.074622  ...       0.113359
# 3                 0.559625    0.000146    0.014690  ...       0.033256
# 4                 0.664442    0.005787    0.005843  ...       0.018126
# ...                    ...         ...         ...  ...            ...
# 818233            0.193217    0.002163    0.103662  ...       0.133231
# 818234            0.376331    0.001019    0.099593  ...       0.116347
# 818235            0.457153    0.006351    0.010818  ...       0.080387
# 818236            0.409706    0.000966    0.027335  ...       0.091375
# 818237            0.410969    0.001405    0.015368  ...       0.038455
#
#         PRI_jet_num  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# 0          0.666667            0.033028             0.738889
# 1          0.333333            0.014316             0.580556
# 2          0.333333            0.012573             0.728111
# 3          0.000000            0.031550             0.500000
# 4          0.000000            0.031550             0.500000
# ...             ...                 ...                  ...
# 818233     0.666667            0.072579             0.632222
# 818234     0.666667            0.069433             0.643667
# 818235     0.000000            0.031550             0.500000
# 818236     0.333333            0.000761             0.662222
# 818237     0.000000            0.031550             0.500000
#
#         PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# 0                  0.570656               0.020388                0.637778
# 1                  0.684278               0.022840                0.498778
# 2                  0.177276               0.022840                0.498778
# 3                  0.492998               0.022840                0.498778
# 4                  0.492998               0.022840                0.498778
# ...                     ...                    ...                     ...
# 818233             0.378103               0.014967                0.587444
# 818234             0.361871               0.050975                0.275778
# 818235             0.492998               0.022840                0.498778
# 818236             0.919637               0.022840                0.498778
# 818237             0.492998               0.022840                0.498778
#
#         PRI_jet_subleading_phi  PRI_jet_all_pt  Label
# 0                     0.106143        0.061014    1.0
# 1                     0.496817        0.024850    0.0
# 2                     0.496817        0.023789    0.0
# 3                     0.496817        0.000000    0.0
# 4                     0.496817        0.000000    0.0
# ...                        ...             ...    ...
# 818233                0.326544        0.082818    1.0
# 818234                0.960376        0.096150    1.0
# 818235                0.496817        0.000000    0.0
# 818236                0.496817        0.016591    0.0
# 818237                0.496817        0.000000    0.0
#
# [818238 rows x 31 columns]>

# %% [markdown]
# ### 6- Split data to Train and test
# Separate *input* data from *target* and split the dataset into train and test (30% for test).

# %%
#détacher l'output

#subdivision des données éch.test = 30%
x_train, x_test, y_train, y_test = model_selection.train_test_split(data_scaled.drop('Label', axis=1), data_scaled['Label'], test_size=0.3, random_state=42)


print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (572766, 30) (245472, 30) (572766,) (245472,)

# %% [markdown]
# ### 7- Apply a dimensionality reduction technique
# Apply the PCA method to reduce training data size while retaining 90% variance.

# %%
# Import PCA class
from sklearn.decomposition import PCA

# Apply PCA with 90% variance retention
pca = PCA(n_components=0.95)
x_train = pca.fit_transform(x_train)
x_test = pca.fit_transform(x_test)

# Convert to DataFrame and include original 'Label' column
x_train = pd.DataFrame(x_train)
x_test = pd.DataFrame(x_test)
print(x_train.shape)
print(x_test.shape)
# Out:
# (572766, 12)
# (245472, 12)

# %% [markdown]
# Creation of a list of performance measures for model comparison

# %%
#for saving results
list_accuracies=[]
list_F1=[]
list_times=[]

# %% [markdown]
# # II- Learning I: Models Only (No additional Paradigms)

# %% [markdown]
# ## 1- Decision Tree

# %% [markdown]
# A decision tree is a supervised machine learning algorithm used for both classification and regression tasks.
# It works by creating a tree-like model of decisions based on features in the data.
#
#  Key characteristics of decision trees:
#  1. Non-linear: Can capture complex relationships in data
#  2. Interpretable: Easy to understand and visualize
#  3. Hierarchical: Makes decisions in a top-down approach
#  4. Prone to overfitting: Can be mitigated by pruning or limiting tree depth
#  5. Handles both numerical and categorical data
#
#  How it works:
#  1. The algorithm starts at the root of the tree with the entire dataset.
#  2. It selects the best feature to split the data based on a criterion (e.g., Gini impurity or information gain).
#  3. The data is split into subsets based on the selected feature's values.
#  4. This process is repeated recursively for each subset, creating new nodes in the tree.
#  5. The process stops when a stopping criterion is met (e.g., max depth, min samples per leaf, or pure subset).
#  6. The final nodes (leaves) represent the predicted class or value.
#
#  In our case, we're using it for classification with a max_depth of 3 to prevent overfitting.

# %%
from sklearn.tree import DecisionTreeClassifier
#création d'une instance d'un classieur DecisionTree
dt_class= DecisionTreeClassifier(max_depth=3)
deb = time.time()
#Si le training échoue, il faut relancer le code
dt_class.fit(x_train, y_train)
fin=time.time()
res_dt = dt_class.predict(x_test)
print("temp",(fin-deb))
list_times.append(fin-deb)
acc=accuracy_score(res_dt,y_test)
F1=f1_score(res_dt,y_test)
print("accuray : ",acc)
print("F1 Score : ", F1)
list_accuracies.append(acc)
list_F1.append(F1)

classes=['Signal','Background']
cm = confusion_matrix(y_test, res_dt, labels=dt_class.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=dt_class.classes_)
disp.plot()
plt.show()
# Out:
# temp 2.559683084487915
# accuray :  0.6895735562508147
# F1 Score :  0.49238926970296504

# %% [markdown]
# ## 2- Logistic Regression

# %% [markdown]
# Logistic Regression is a statistical method used for binary classification problems. Despite its name, it's used for classification rather than regression tasks. Here's an overview of how it works:
#
# 1. Linear combination: It creates a linear combination of input features.
# 2. Sigmoid function: The linear combination is passed through a sigmoid function to produce a probability between 0 and 1.
# 3. Decision boundary: A threshold (usually 0.5) is used to classify the output probability into one of two classes.
# 4. Optimization: The model parameters are optimized using techniques like maximum likelihood estimation or gradient descent.
#
#  Key characteristics:
# 1. Interpretable: The coefficients can be interpreted as the importance of each feature.
# 2. Efficient: Works well for linearly separable classes and with large datasets.
# 3. Probabilistic output: Provides probability estimates for predictions.
# 4. Assumes linearity: May not perform well with highly non-linear relationships.
#
# In our case, we're using the 'sag' solver, which is suitable for large datasets and uses a stochastic average gradient descent method for optimization.

# %%
from sklearn.linear_model import LogisticRegression
lg_clf = LogisticRegression(solver='sag')
#Le solveur par défaut pour logistic regression est , "liblinear" adapté pour les problèmes de petite et moyenne taille
#sag" : est un solveur basé sur l'optimisation stochastique (méthode de gradient moyen stochastique).
#Il est adaptée aux problèmes de grande taille.
deb = time.time()
lg_clf.fit(x_train, y_train)
fin=time.time()
res_lg = lg_clf.predict(x_test)
print("temp",(fin-deb))
list_times.append(fin-deb)
acc=accuracy_score(res_lg,y_test)
F1=f1_score(res_lg,y_test)
print("accuray : ",acc)
print("F1 Score : ", F1)
list_accuracies.append(acc)
list_F1.append(F1)

classes=['Signal','Background']
cm = confusion_matrix(y_test, res_dt, labels=dt_class.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=dt_class.classes_)
disp.plot()
plt.show()
# Out:
# temp 4.175271987915039
# accuray :  0.6883677160735236
# F1 Score :  0.3900393101193656

# %% [markdown]
# ##  3- Baysien

# %% [markdown]
# Bayesian models are probabilistic models based on Bayes' theorem. They work by updating prior beliefs about parameters or hypotheses using observed data to form posterior probabilities. In machine learning, Naive Bayes is a popular Bayesian model.
#
# Naive Bayes classifiers work as follows:
# 1. They assume features are independent given the class (the "naive" assumption).
# 2. They use Bayes' theorem to calculate the probability of each class given the input features.
# 3. They select the class with the highest probability as the prediction.
#
# Key characteristics of Bayesian models:
# 1. Probabilistic: They provide probability estimates for predictions.
# 2. Incorporate prior knowledge: Can use prior probabilities in the model.
# 3. Handle uncertainty: Can work well with limited or noisy data.
# 4. Efficient: Often fast to train and make predictions, especially Naive Bayes.
#
# In our case, we're using Gaussian Naive Bayes, which assumes the features follow a Gaussian distribution within each class.

# %%
from sklearn.naive_bayes import GaussianNB
gn_clf=GaussianNB()
deb = time.time()
gn_clf.fit(x_train, y_train)
fin=time.time()
res_gn = gn_clf.predict(x_test)
print("temp",(fin-deb))
list_times.append(fin-deb)
acc=accuracy_score(res_gn,y_test)
F1=f1_score(res_gn,y_test)
print("accuray : ",acc)
print("F1 Score : ", F1)
list_accuracies.append(acc)
list_F1.append(F1)
classes=['Signal','Background']
cm = confusion_matrix(y_test, res_dt, labels=dt_class.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=dt_class.classes_)
disp.plot()
plt.show()
# Out:
# temp 0.056221961975097656
# accuray :  0.6916023008734193
# F1 Score :  0.48718695596214684

# %% [markdown]
# ### Plotting results

# %%
x = ['DT', 'LR', 'Gauss']
plt.grid()
plt.plot(x,list_accuracies)
plt.plot(x,list_F1,'r')
plt.legend(['Accuracy', 'F1 Score'])
plt.show()

# %%
#figures des temps de calcul
plt.grid()
plt.plot(x,list_times)
plt.legend(['Time'])
plt.show()

# %% [markdown]
# # II- Learning II: Ensemble Learning

# %% [markdown]
# # Ensemble Learning
#
# Ensemble learning is a machine learning technique that combines multiple individual models to create a more robust and accurate predictive model. The main idea behind ensemble methods is that by combining several models, we can overcome the limitations and biases of individual models, leading to better overall performance.
#
# Key concepts of ensemble learning:
#
# 1. Base learners: Individual models that make up the ensemble (e.g., decision trees, neural networks, SVMs)
# 2. Diversity: Ensuring that base learners are different from each other to capture various aspects of the data
# 3. Combination method: How predictions from base learners are combined (e.g., voting, averaging, weighted averaging)
#
# Common ensemble learning techniques:
#
# 1. Bagging (Bootstrap Aggregating): Creates multiple subsets of the original dataset and trains a model on each subset
# 2. Boosting: Sequentially trains models, with each new model focusing on the errors of the previous ones
# 3. Stacking: Uses predictions from multiple models as inputs for a meta-model
#
# Benefits of ensemble learning:
# - Improved prediction accuracy
# - Reduced overfitting
# - Increased model stability
# - Better handling of complex relationships in data
#
# Ensemble methods are widely used in various machine learning applications and competitions due to their effectiveness in improving model performance.

# %% [markdown]
# ## II-1 Bagging

# %%
n_estimators=100

# %% [markdown]
# Bagging (Bootstrap Aggregating)
#
# Bagging is an ensemble learning technique that combines multiple models to improve prediction accuracy and reduce overfitting.
#
# How it works:
# 1. Create multiple subsets of the original dataset using bootstrap sampling (random sampling with replacement)
# 2. Train a separate model on each subset
# 3. Combine predictions from all models:
#    - For classification: use majority voting
#    - For regression: use averaging
#
# Advantages of Bagging:
# - Reduces overfitting
# - Improves stability and accuracy
# - Works well with high-variance models (e.g., decision trees)
#
# Common implementations:
# - Random Forest: Bagging with decision trees and random feature selection
# - Bagging Classifier/Regressor: Can use any base estimator (e.g., logistic regression, neural networks)

# %% [markdown]
# ### Random Forest
# class sklearn.ensemble.RandomForestClassifier(n_estimators=100, *, criterion='gini', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='sqrt', max_leaf_nodes=None, min_impurity_decrease=0.0, bootstrap=True, oob_score=False, n_jobs=None, random_state=None, verbose=0, warm_start=False, class_weight=None, ccp_alpha=0.0, max_samples=None)

# %%
from sklearn.ensemble import RandomForestClassifier
deb = time.time()
rf_etc=RandomForestClassifier(n_estimators=n_estimators,max_depth=3, random_state=0, n_jobs=-1)
rf_etc.fit(x_train,y_train)
fin=time.time()
list_times.append(fin-deb)
print("temp RF ",(fin-deb))
res_rf=rf_etc.predict(x_test)
acc=accuracy_score(res_rf,y_test)
F1=f1_score(res_rf,y_test)
print("accuray RF ", acc)
print("F1 Score : ", F1)
list_accuracies.append(acc)
list_F1.append(F1)
cm = confusion_matrix(y_test, res_rf, labels=rf_etc.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=rf_etc.classes_)
disp.plot()
plt.show()
# Out:
# temp RF  7.313316106796265
# accuray RF  0.7034733085647242
# F1 Score :  0.3065270619170565

# %% [markdown]
# ### Bagging classifier with Logistic Regression
# class sklearn.ensemble.BaggingClassifier(estimator=None, n_estimators=10, *, max_samples=1.0, max_features=1.0, bootstrap=True, bootstrap_features=False, oob_score=False, warm_start=False, n_jobs=None, random_state=None, verbose=0, base_estimator='deprecated')

# %%
from sklearn.ensemble import BaggingClassifier
#max_samples: taille maximale de l'échantillon par rapport à l'échantillon initial
#max_features: nombre d'attributs à sélectionner d'une façon aléatoire
# max_features=1,random_state=0
bagging = BaggingClassifier(LogisticRegression(),n_estimators=n_estimators,max_samples=0.7, max_features=0.7, random_state=42)
deb = time.time()
bagging.fit(x_train, y_train)
fin=time.time()
list_times.append(fin-deb)
res_bag = bagging.predict(x_test)
print("temp RF ",(fin-deb))
acc=accuracy_score(res_bag,y_test)
F1=f1_score(res_bag,y_test)
print("accuray RF ", acc)
print("F1 Score : ", F1)
list_accuracies.append(acc)
list_F1.append(F1)
cm = confusion_matrix(y_test, res_bag, labels=rf_etc.classes_)
print(cm)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=rf_etc.classes_)
disp.plot()
plt.show()
# Out:
# temp RF  13.73282504081726
# accuray RF  0.6919607938991005
# F1 Score :  0.29172247773021476
# [[154285   7230]
#  [ 68385  15572]]

# %% [markdown]
# ### Bagging classifier with Baysian
# class sklearn.ensemble.BaggingClassifier(estimator=None, n_estimators=10, *, max_samples=1.0, max_features=1.0, bootstrap=True, bootstrap_features=False, oob_score=False, warm_start=False, n_jobs=None, random_state=None, verbose=0, base_estimator='deprecated')

# %%
#max_samples: taille maximale de l'échantillon par rapport à l'échantillon initial
#max_features: nombre d'attributs à sélectionner d'une façon aléatoire
# max_features=1,random_state=0
bagging = BaggingClassifier(GaussianNB(),n_estimators=n_estimators,max_samples=0.5, max_features=0.5,random_state=42)
deb = time.time()
bagging.fit(x_train, y_train)
fin=time.time()
list_times.append(fin-deb)
res_bag = bagging.predict(x_test)
print("temp RF ",(fin-deb))
acc=accuracy_score(res_bag,y_test)
F1=f1_score(res_bag,y_test)
print("accuray RF ", acc)
print("F1 Score : ", F1)
list_accuracies.append(acc)
list_F1.append(F1)
cm = confusion_matrix(y_test, res_bag, labels=rf_etc.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=rf_etc.classes_)
disp.plot()
plt.show()
# Out:
# temp RF  4.9190051555633545
# accuray RF  0.6957249706687525
# F1 Score :  0.42919917770322424

# %% [markdown]
# ### Plotting results

# %%
x = ['DT', 'LR', 'Gauss', "RF", "Bag LR", "Bag Gauss"]
plt.grid()
plt.plot(x,list_accuracies)
plt.plot(x,list_F1,'r')
plt.legend(['Accuracy', 'F1 Score'])
plt.show()

# %%
plt.grid()
plt.plot(x,list_times)
plt.legend(['Time'])
plt.show()

# %% [markdown]
# # Exercice:
# Vary the values of the 'n_estimators' parameter to visualize the effect of the number of models in ensemble learning on classifier quality.

# %% [markdown]
# ## II - 2- Boosting

# %% [markdown]
# Boosting
#
# Boosting is an ensemble learning technique that combines multiple weak learners to create a strong learner. The key idea behind boosting is to train models sequentially, with each new model focusing on the mistakes made by the previous models.
#
# How boosting works:
# 1. Start with a weak learner (e.g., a shallow decision tree).
# 2. Train the weak learner on the dataset.
# 3. Identify the misclassified instances.
# 4. Increase the weight or importance of misclassified instances.
# 5. Train a new weak learner on the updated dataset with adjusted weights.
# 6. Repeat steps 3-5 for a specified number of iterations.
# 7. Combine the predictions of all weak learners to make the final prediction.
#
# Boosting algorithms differ in how they adjust weights and combine weak learners. Two popular boosting algorithms are AdaBoost and Gradient Boosting, which we'll explore in the following sections.

# %% [markdown]
# ### AdaBoost
# lass sklearn.ensemble.AdaBoostClassifier(estimator=None, *, n_estimators=50, learning_rate=1.0, algorithm='SAMME.R', random_state=None, base_estimator='deprecated')
#
# An AdaBoost classifier is a meta-estimator that begins by fitting a classifier on the original dataset and then fits additional copies of the classifier on the same dataset but where the weights of incorrectly classified instances are adjusted such that subsequent classifiers focus more on difficult cases.

# %%
from sklearn.ensemble import AdaBoostClassifier
deb = time.time()
ada_clf = AdaBoostClassifier(n_estimators=n_estimators, learning_rate=0.2, random_state=42)
ada_clf.fit(x_train, y_train)
fin=time.time()
list_times.append(fin-deb)
res_ada = ada_clf.predict(x_test)
print("temp RF ",(fin-deb))
acc=accuracy_score(res_ada,y_test)
F1=f1_score(res_ada,y_test)
print("accuray RF ", acc)
print("F1 Score : ", F1)
list_accuracies.append(acc)
list_F1.append(F1)
cm = confusion_matrix(y_test, res_ada, labels=rf_etc.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=rf_etc.classes_)
disp.plot()
plt.show()
# Out:
# /Users/alexs/PycharmProjects/AppliedML2/.venv/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# temp RF  86.66399693489075
# accuray RF  0.7091032785816712
# F1 Score :  0.4482750627776705

# %% [markdown]
# ## Gradient Boost (Gradient Boosted Decision Trees)
#
# This algorithm builds an additive model in a forward stage-wise fashion; it allows for the optimization of arbitrary differentiable loss functions. In each stage n_classes_ regression trees are fit on the negative gradient of the loss function, e.g. binary or multiclass log loss. Binary classification is a special case where only a single regression tree is induced.
#
# class sklearn.ensemble.GradientBoostingClassifier(*, loss='log_loss', learning_rate=0.1, n_estimators=100, subsample=1.0, criterion='friedman_mse', min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_depth=3, min_impurity_decrease=0.0, init=None, random_state=None, max_features=None, verbose=0, max_leaf_nodes=None, warm_start=False, validation_fraction=0.1, n_iter_no_change=None, tol=0.0001, ccp_alpha=0.0

# %%
from sklearn.ensemble import GradientBoostingClassifier
deb = time.time()
gb_clf = GradientBoostingClassifier(n_estimators=n_estimators, learning_rate=0.2, random_state=42)
gb_clf.fit(x_train, y_train)
fin=time.time()
list_times.append(fin-deb)
res_gb = gb_clf.predict(x_test)
print("temp RF ",(fin-deb))
acc=accuracy_score(res_gb,y_test)
F1=f1_score(res_gb,y_test)
print("accuray RF ", acc)
print("F1 Score : ", F1)
list_accuracies.append(acc)
list_F1.append(F1)
cm = confusion_matrix(y_test, res_gb, labels=rf_etc.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=rf_etc.classes_)
disp.plot()
plt.show()
# Out:
# temp RF  227.54628086090088
# accuray RF  0.7301362273497588
# F1 Score :  0.5312415969657085

# %%
x = ['DT', 'LR', 'Gauss', "RF", "Bag LR", "Bag Gauss", "AdaBoost", "GdBoost" ]
plt.grid()
plt.plot(x,list_accuracies)
plt.plot(x,list_F1,'r')
plt.legend(['Accuracy', 'F1 Score'])
plt.xticks(rotation=45, ha='right')
plt.show()
plt.grid()
plt.plot(x,list_times)
plt.legend(['Time'])
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# # V- Learning IV : Unbalance Learning

# %% [markdown]
# Unbalanced learning refers to a situation in machine learning where the classes in a dataset are not represented equally. This imbalance can significantly impact the performance of machine learning models, as they tend to be biased towards the majority class.
#
# In unbalanced learning, we employ various techniques to address this issue:
#
# 1. Resampling methods:
#    - Undersampling: Reducing the number of samples in the majority class.
#    - Oversampling: Increasing the number of samples in the minority class.
#    - Synthetic sampling (e.g., SMOTE): Creating synthetic examples of the minority class.
#
# 2. Algorithm-level approaches:
#    - Adjusting class weights: Giving more importance to the minority class during training.
#    - Ensemble methods: Combining multiple models to improve performance on imbalanced data.
#
# 3. Performance metrics:
#    - Using metrics like F1-score, precision-recall curve, or ROC AUC that are more suitable for imbalanced datasets.
#
# The goal of unbalanced learning is to develop models that perform well across all classes, not just the majority class, thereby improving overall predictive accuracy and reliability.

# %% [markdown]
# ### Sampling methods to be tested:
#
#
# *   Under Sampling (US)
# *   Over  Samplig (OS)
# *   SMOTE (synthetic sampling)
# *   BSMOTE (Borderline Sampling)

# %%
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler, SMOTE, BorderlineSMOTE
#Under Sampling
us = RandomUnderSampler(random_state=1)
x_us, y_us = us.fit_resample(x_train, y_train)
#Over Sampling
os = RandomOverSampler(random_state=1)
x_os, y_os = os.fit_resample(x_train, y_train)

#SMOTE # heavy in execution!!!!
sm = SMOTE(random_state=1)
x_sm, y_sm = sm.fit_resample(x_train, y_train)
#Borderline SMOTE  #lourd en excution !!!!
bl = BorderlineSMOTE(random_state=1)
x_bl, y_bl = bl.fit_resample(x_train, y_train)

# %% [markdown]
# ## Decision Tree avec des **échantillons** balancés

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import time

dt_class = DecisionTreeClassifier()

# List of sampling methods
sampling_methods = [
    ('Under Sampling', x_us, y_us),
    ('Over Sampling', x_os, y_os),
    ('SMOTE', x_sm, y_sm),
    ('Borderline SMOTE', x_bl, y_bl)
]

for method_name, X, y in sampling_methods:
    print(f"\n--- Decision Tree with {method_name} ---")
    
    deb = time.time()
    dt_class.fit(X, y)
    fin = time.time()
    
    res_dt = dt_class.predict(x_test)
    
    print("Time:", (fin-deb))
    acc = accuracy_score(res_dt, y_test)
    F1 = f1_score(res_dt, y_test)
    print("Accuracy:", acc)
    print("F1 Score:", F1)
    list_times.append(fin-deb)
    list_accuracies.append(acc)
    list_F1.append(F1)
    
    classes = ['Signal', 'Background']
    cm = confusion_matrix(y_test, res_dt, labels=dt_class.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=dt_class.classes_)
    disp.plot()
    plt.title(f"Confusion Matrix - {method_name}")
    plt.show()
# Out:
# --- Decision Tree with Under Sampling ---
# Time: 9.452900648117065
# Accuracy: 0.6040811171946291
# F1 Score: 0.512419415527405
# --- Decision Tree with Over Sampling ---
# Time: 18.700686931610107
# Accuracy: 0.6348504106374658
# F1 Score: 0.47347830684101083
# --- Decision Tree with SMOTE ---
# Time: 20.314817190170288
# Accuracy: 0.6256884695606831
# F1 Score: 0.49846892824977485
# --- Decision Tree with Borderline SMOTE ---
# Time: 20.77794885635376
# Accuracy: 0.625
# F1 Score: 0.4997608903573602

# %% [markdown]
# ## Classification with Baysian on balanced data

# %%
from sklearn.naive_bayes import GaussianNB

for method_name, X, y in sampling_methods:
    print(f"\n--- Gaussian Naive Bayes with {method_name} ---")
    
    gn_clf = GaussianNB()
    deb = time.time()
    gn_clf.fit(X, y)
    fin = time.time()
    
    res_gn = gn_clf.predict(x_test)
    
    print("Time:", (fin-deb))
    acc = accuracy_score(res_gn, y_test)
    F1 = f1_score(res_gn, y_test)
    print("Accuracy:", acc)
    print("F1 Score:", F1)
    list_times.append(fin-deb)
    list_accuracies.append(acc)
    list_F1.append(F1)
    
    classes = ['Signal', 'Background']
    cm = confusion_matrix(y_test, res_gn, labels=gn_clf.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=gn_clf.classes_)
    disp.plot()
    plt.title(f"Confusion Matrix - {method_name}")
    plt.show()
# Out:
# --- Gaussian Naive Bayes with Under Sampling ---
# Time: 0.051869869232177734
# Accuracy: 0.6725003259027507
# F1 Score: 0.5353385892308048
# --- Gaussian Naive Bayes with Over Sampling ---
# Time: 0.1012110710144043
# Accuracy: 0.672667351062443
# F1 Score: 0.5357768058837463
# --- Gaussian Naive Bayes with SMOTE ---
# Time: 0.06708097457885742
# Accuracy: 0.674186872637205
# F1 Score: 0.5392229161385477
# --- Gaussian Naive Bayes with Borderline SMOTE ---
# Time: 0.06531500816345215
# Accuracy: 0.6622140203363316
# F1 Score: 0.555683565805902

# %%
x = ['DT', 'LR', 'Gauss', "RF", "Bag LR", "Bag Gauss", "AdaBoost", "GdBoost" , "DT US", "DT OS", "DT SMOTE", "DT BSMOTE", "GN US", "GN OS", "GN SMOTE", "GN BSMOTE"]
plt.grid()
plt.plot(x,list_accuracies)
plt.plot(x,list_F1,'r')
plt.legend(['Accuracy', 'F1 Score'])
plt.xticks(rotation=45, ha='right')
plt.show()
plt.grid()
plt.plot(x,list_times)
plt.legend(['Time'])
plt.xticks(rotation=45, ha='right')
plt.show()
